# %%
import os
import numpy as np
#import pandas as pd

# %%
# 設定 data_path
# dir_data = '.\data'
dir_data = '..\data'

# %%
#print(os.getcwd())
print(os.listdir(path='..'))
# Out:
# ['.git', 'data', 'homework', 'README.md']

# %%
f_app = os.path.join(dir_data, 'application_train.csv')
print('Path of read in data: %s' % (f_app))
app_train = pd.read_csv(f_app)

print(type(app_train))
# Out:
# Path of read in data: ..\data\application_train.csv
# <class 'pandas.core.frame.DataFrame'>

# %%
# 資料的 row 數以及 column 數
app_train.shape
# Out:
# (307511, 122)

# %%
# 列出所有欄位
app_train.head()
# Out:
#    SK_ID_CURR  TARGET NAME_CONTRACT_TYPE CODE_GENDER FLAG_OWN_CAR  \
# 0      100002       1         Cash loans           M            N
# 1      100003       0         Cash loans           F            N
# 2      100004       0    Revolving loans           M            Y
# 3      100006       0         Cash loans           F            N
# 4      100007       0         Cash loans           M            N
#
#   FLAG_OWN_REALTY  CNT_CHILDREN  AMT_INCOME_TOTAL  AMT_CREDIT  AMT_ANNUITY  \
# 0               Y             0          202500.0    406597.5      24700.5
# 1               N             0          270000.0   1293502.5      35698.5
# 2               Y             0           67500.0    135000.0       6750.0
# 3               Y             0          135000.0    312682.5      29686.5
# 4               Y             0          121500.0    513000.0      21865.5
#
#               ...              FLAG_DOCUMENT_18 FLAG_DOCUMENT_19  \
# ...

# %%
# 截取部分資料
#app_train[['NAME_CONTRACT_TYPE','CODE_GENDER','FLAG_OWN_CAR']]
#app_train[app_train['CODE_GENDER'] == 'M']
#app_train[(app_train['CODE_GENDER'] == 'M') & (app_train['FLAG_OWN_CAR'] == 'Y')]
#app_train[app_train['FLAG_OWN_CAR'] =='Y'].groupby(by = 'NAME_CONTRACT_TYPE')[['AMT_INCOME_TOTAL','AMT_CREDIT']].mean()
app_train[app_train['FLAG_OWN_CAR'] =='Y'][['NAME_CONTRACT_TYPE','CODE_GENDER','FLAG_OWN_CAR']]
# Out:
#        NAME_CONTRACT_TYPE CODE_GENDER FLAG_OWN_CAR
# 2         Revolving loans           M            Y
# 6              Cash loans           F            Y
# 7              Cash loans           M            Y
# 13             Cash loans           M            Y
# 15             Cash loans           M            Y
# 20        Revolving loans           M            Y
# 21             Cash loans           F            Y
# 24             Cash loans           M            Y
# 28             Cash loans           M            Y
# 33             Cash loans           M            Y
# 39        Revolving loans           M            Y
# 49             Cash loans           M            Y
# 51             Cash loans           M            Y
# 52             Cash loans           M            Y
# 54             Cash loans           M            Y
# 58             Cash loans           M            Y
# 59             Cash loans           M            Y
# ...
