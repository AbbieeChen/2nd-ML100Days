# %%
HW1:
    DataSet: NOAA ICOADS
    1.) 現在地球海洋及氣候過於糟糕，是值得被關注的議題
    2.) 資料是由美國國家海洋和大氣管理局所提供的，資料搜集的方式有海上浮標、海洋觀測站和海軍、研究的船舶...等
    3.) 資料為非結構化資料，包括日期、數值、型態類別
    4.) 參考相關大氣科學的論文研究

# %%
HW2:
    1.) 假設自由載客車隊有提供電話叫車或APP叫車服務，可借由服務增加車隊的調度，
        再借由系統詢問客戶滿意度，滿意度增加同時在市場上口碑也會增加，讓車隊的業績也相對提升
    2.) 一開始從電話記錄及APP記錄，記錄客戶資料(例如: 姓名、電話)，再記錄配出去的車子是那一台，
        車子服務完後，發送問卷請客戶填寫服務過程的滿意度
    3.) 搜集為結構化資料，包括日期、數字，文字、型態類別
    4.) 初期可以比較每月的載客率是否有提升

# %%
import numpy as np
import matplotlib.pyplot as plt

w = 3
b = 0.5

x_lin = np.linspace(0, 100, 101)

y = (x_lin + np.random.randn(101) * 5) * w + b

plt.plot(x_lin, y, 'b.', label = 'data points')
plt.title("Assume we have data points")
plt.legend(loc = 2)
plt.show()

# %%
y_hat = x_lin * w + b
plt.plot(x_lin, y, 'b.', label = 'data')
plt.plot(x_lin, y_hat, 'r-', label = 'prediction')
plt.title("Assume we have data points (And the prediction)")
plt.legend(loc = 2)
plt.show()

# %%
def mean_absolute_error(y, yp):
    """
    計算 MAE
    Args:
        - y: 實際值
        - yp: 預測值
    Return:
        - mae: MAE
    """
    mae = MAE = sum(abs(y - yp)) / len(y)
    return mae

MAE = mean_absolute_error(y, y_hat)
print("The Mean absolute error is %.3f" % (MAE))
# Out:
# The Mean absolute error is 14.117

# %%
def mean_square_error(y, yp):
    """
    
    """
    mse = MSE = sum((y - yp)**2) / len(y)
    return mse

MSE = mean_square_error(y, y_hat)
print("The Mean queare error is %.3f" % (MSE))
# Out:
# The Mean queare error is 281.114
